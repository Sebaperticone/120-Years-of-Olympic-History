# %% [markdown]
# <a href="https://colab.research.google.com/github/Sebaperticone/120-Years-of-Olympic-History/blob/main/ProyectoParteIII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Sebaperticone/Olymps/b5711dedb94fa1c42370e1e295d8b5e94acdaa50/athlete_events.csv.zip")

# %%
df = df.set_index(["ID"])

# %%
df.shape
# Out:
# (271116, 14)

# %%
print("Le pido que me muestre las primeras 15 filas")
df.head(15)
# Out:
# Le pido que me muestre las primeras 15 filas
#                         Name Sex   Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China  CHN
# 2                   A Lamusi   M  23.0   170.0    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands  NED
# 6            Per Knut Aaland   M  31.0   188.0    75.0   United States  USA
# ...

# %%
print ("Le pido que me muestre las primeras 5 filas")
df.head()
# Out:
# Le pido que me muestre las primeras 5 filas
#                         Name Sex   Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China  CHN
# 2                   A Lamusi   M  23.0   170.0    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
#
#           Games  Year  Season       City          Sport  \
# ID
# 1   1992 Summer  1992  Summer  Barcelona     Basketball
# 2   2012 Summer  2012  Summer     London           Judo
# 3   1920 Summer  1920  Summer  Antwerpen       Football
# 4   1900 Summer  1900  Summer      Paris     Tug-Of-War
# 5   1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                                Event Medal
# ID
# 1        Basketball Men's Basketball   NaN
# ...

# %%
print ("Le pido que me muestre las últimas 10 filas")
df.tail(10)
# Out:
# Le pido que me muestre las últimas 10 filas
#                                 Name Sex   Age  Height  Weight           Team  \
# ID
# 135565      Fernando scar Zylberberg   M  27.0   168.0    76.0      Argentina
# 135566    James Francis "Jim" Zylker   M  21.0   175.0    75.0  United States
# 135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0         Russia
# 135567  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0         Russia
# 135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0        Belarus
# 135569                    Andrzej ya   M  29.0   179.0    89.0       Poland-1
# 135570                      Piotr ya   M  27.0   176.0    59.0         Poland
# 135570                      Piotr ya   M  27.0   176.0    59.0         Poland
# 135571            Tomasz Ireneusz ya   M  30.0   185.0    96.0         Poland
# 135571            Tomasz Ireneusz ya   M  34.0   185.0    96.0         Poland
#
# ...

# %%
print("Le pido la descripción del DF")
df.describe()
# Out:
# Le pido la descripción del DF
#                  Age         Height         Weight           Year
# count  261642.000000  210945.000000  208241.000000  271116.000000
# mean       25.556898     175.338970      70.702393    1978.378480
# std         6.393561      10.518462      14.348020      29.877632
# min        10.000000     127.000000      25.000000    1896.000000
# 25%        21.000000     168.000000      60.000000    1960.000000
# 50%        24.000000     175.000000      70.000000    1988.000000
# 75%        28.000000     183.000000      79.000000    2002.000000
# max        97.000000     226.000000     214.000000    2016.000000

# %%
print ("Le pido las columnas del DF")
df.columns
# Out:
# Le pido las columnas del DF
# Index(['Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 271116 entries, 1 to 135571
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    271116 non-null  object
#  1   Sex     271116 non-null  object
#  2   Age     261642 non-null  float64
#  3   Height  210945 non-null  float64
#  4   Weight  208241 non-null  float64
#  5   Team    271116 non-null  object
#  6   NOC     271116 non-null  object
#  7   Games   271116 non-null  object
#  8   Year    271116 non-null  int64
#  9   Season  271116 non-null  object
#  10  City    271116 non-null  object
#  11  Sport   271116 non-null  object
#  12  Event   271116 non-null  object
#  13  Medal   39783 non-null   object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 31.0+ MB

# %%
print("Le pido la cantidad de valores no nulos y el tipo de cada variable")
print(df.info())
# Out:
# Le pido la cantidad de valores no nulos y el tipo de cada variable
# <class 'pandas.core.frame.DataFrame'>
# Index: 271116 entries, 1 to 135571
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    271116 non-null  object
#  1   Sex     271116 non-null  object
#  2   Age     261642 non-null  float64
#  3   Height  210945 non-null  float64
#  4   Weight  208241 non-null  float64
#  5   Team    271116 non-null  object
#  6   NOC     271116 non-null  object
#  7   Games   271116 non-null  object
#  8   Year    271116 non-null  int64
#  9   Season  271116 non-null  object
#  10  City    271116 non-null  object
#  11  Sport   271116 non-null  object
#  12  Event   271116 non-null  object
#  13  Medal   39783 non-null   object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 31.0+ MB
# None

# %%
print(df)
# Out:
#                             Name Sex   Age  Height  Weight            Team  \
# ID
# 1                      A Dijiang   M  24.0   180.0    80.0           China
# 2                       A Lamusi   M  23.0   170.0    60.0           China
# 3            Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 4           Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# 135569                Andrzej ya   M  29.0   179.0    89.0        Poland-1
# 135570                  Piotr ya   M  27.0   176.0    59.0          Poland
# 135570                  Piotr ya   M  27.0   176.0    59.0          Poland
# 135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0          Poland
# 135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0          Poland
#
# ...

# %%
print("Le pido que me muestre los mayores a 34 años de edad")
df[df["Age"] > 34]
# Out:
# Le pido que me muestre los mayores a 34 años de edad
#                          Name Sex   Age  Height  Weight     Team  NOC  \
# ID
# 19      Win Valdemar Aaltonen   M  54.0     NaN     NaN  Finland  FIN
# 28           Jan-Erik Aarberg   M  43.0   170.0    77.0   Norway  NOR
# 28           Jan-Erik Aarberg   M  47.0   170.0    77.0   Norway  NOR
# 45                Hakon Aasns   M  41.0     NaN     NaN   Norway  NOR
# 46                 Hans Aasns   M  45.0   194.0    93.0   Norway  NOR
# ...                       ...  ..   ...     ...     ...      ...  ...
# 135554           Bogusaw Zych   M  36.0   182.0    82.0   Poland  POL
# 135554           Bogusaw Zych   M  36.0   182.0    82.0   Poland  POL
# 135554           Bogusaw Zych   M  36.0   182.0    82.0   Poland  POL
# 135557           Dominik ycki   M  38.0   192.0    95.0   Poland  POL
# 135560      Stavroula Zygouri   F  36.0   171.0    63.0   Greece  GRE
#
#               Games  Year  Season         City             Sport  \
# ...

# %%
print("Le pido trasponer las variables")
df.describe().T
# Out:
# Le pido trasponer las variables
#            count         mean        std     min     25%     50%     75%  \
# Age     261642.0    25.556898   6.393561    10.0    21.0    24.0    28.0
# Height  210945.0   175.338970  10.518462   127.0   168.0   175.0   183.0
# Weight  208241.0    70.702393  14.348020    25.0    60.0    70.0    79.0
# Year    271116.0  1978.378480  29.877632  1896.0  1960.0  1988.0  2002.0
#
#            max
# Age       97.0
# Height   226.0
# Weight   214.0
# Year    2016.0

# %%
print("Le pido que me muestre los valores únicos de deportes")
df.Sport.unique()
# Out:
# Le pido que me muestre los valores únicos de deportes
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
# ...

# %%
print("Le pido que me muestre la cantidad de valores únicos de deportes")
print(df["Sport"].value_counts())
# Out:
# Le pido que me muestre la cantidad de valores únicos de deportes
# Sport
# Athletics        38624
# Gymnastics       26707
# Swimming         23195
# Shooting         11448
# Cycling          10859
#                  ...
# Racquets            12
# Jeu De Paume        11
# Roque                4
# Basque Pelota        2
# Aeronautics          1
# Name: count, Length: 66, dtype: int64

# %%
df.isna().sum()
# Out:
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_title('Gráfico de Ejemplo')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_title('Gráfico de Ejemplo')
plt.show()
